# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

IMG_SIZE = 128
BATCH_SIZE = 32
AUTOTUNE = tf.data.AUTOTUNE

def preprocess(image, label):
    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

def augment(image, label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_brightness(image, max_delta=0.1)
    image = tf.image.random_contrast(image, 0.8, 1.2)
    return image, label

(raw_train, raw_val), ds_info = tfds.load(
    'malaria',
    split=['train[:80%]', 'train[80%:]'],
    as_supervised=True,
    with_info=True
)

train = (
    raw_train.map(preprocess, num_parallel_calls=AUTOTUNE)
    .map(augment, num_parallel_calls=AUTOTUNE)
    .shuffle(1000)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

val = (
    raw_val.map(preprocess, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/malaria/1.0.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/malaria/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/malaria/incomplete.MZX2R9_1.0.0/malaria-train.tfrecord*...:   0%|         …
# Dataset malaria downloaded and prepared to /root/tensorflow_datasets/malaria/1.0.0. Subsequent calls will reuse this data.

# %%
def build_model():
    model = models.Sequential([
        layers.Conv2D(32, (3,3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)),
        layers.BatchNormalization(),
        layers.MaxPooling2D(2, 2),

        layers.Conv2D(64, (3,3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(2, 2),

        layers.Conv2D(128, (3,3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(2, 2),

        layers.Conv2D(256, (3,3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(2, 2),

        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
        loss='binary_crossentropy',
        metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
    )
    return model

model = build_model()
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 126, 126, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 61, 61, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 28, 28, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,179,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,570,241 (5.99 MB)
#  Trainable params: 1,569,281 (5.99 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint_cb = ModelCheckpoint(
    "best_model.h5",
    save_best_only=True,
    monitor="val_loss",
    mode="min",
    verbose=1
)

lr_reduce_cb = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    verbose=1,
    min_lr=1e-7
)

earlystop_cb = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True,
    verbose=1
)

history = model.fit(
    train,
    epochs=100,
    validation_data=val,
    callbacks=[checkpoint_cb, earlystop_cb, lr_reduce_cb]
)
# Out:
# Epoch 1/100
# 688/689 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9685 - loss: 0.0908 - precision: 0.9615 - recall: 0.9766
# Epoch 1: val_loss improved from inf to 0.14700, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 26s 37ms/step - accuracy: 0.9685 - loss: 0.0908 - precision: 0.9615 - recall: 0.9766 - val_accuracy: 0.9561 - val_loss: 0.1470 - val_precision: 0.9591 - val_recall: 0.9520 - learning_rate: 1.0000e-04
# Epoch 2/100
# 688/689 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9694 - loss: 0.0857 - precision: 0.9620 - recall: 0.9783
# Epoch 2: val_loss improved from 0.14700 to 0.13264, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 26s 37ms/step - accuracy: 0.9694 - loss: 0.0857 - precision: 0.9620 - recall: 0.9783 - val_accuracy: 0.9586 - val_loss: 0.1326 - val_precision: 0.9533 - val_recall: 0.9638 - learning_rate: 1.0000e-04
# Epoch 3/100
# 687/689 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9702 - loss: 0.0827 - precision: 0.9629 - recall: 0.9787
# Epoch 3: val_loss did not improve from 0.13264
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 41s 37ms/step - accuracy: 0.9701 - loss: 0.0827 - precision: 0.9629 - recall: 0.9787 - val_accuracy: 0.9563 - val_loss: 0.1419 - val_precision: 0.9415 - val_recall: 0.9722 - learning_rate: 1.0000e-04
# Epoch 4/100
# 688/689 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9734 - loss: 0.0786 - precision: 0.9659 - recall: 0.9817
# Epoch 4: val_loss did not improve from 0.13264
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 28s 39ms/step - accuracy: 0.9734 - loss: 0.0786 - precision: 0.9659 - recall: 0.9817 - val_accuracy: 0.9592 - val_loss: 0.1396 - val_precision: 0.9507 - val_recall: 0.9678 - learning_rate: 1.0000e-04
# Epoch 5/100
# 688/689 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9729 - loss: 0.0722 - precision: 0.9656 - recall: 0.9812
# Epoch 5: val_loss did not improve from 0.13264
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.9729 - loss: 0.0722 - precision: 0.9656 - recall: 0.9812 - val_accuracy: 0.9570 - val_loss: 0.1515 - val_precision: 0.9568 - val_recall: 0.9564 - learning_rate: 1.0000e-04
# Epoch 6/100
# 687/689 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9735 - loss: 0.0733 - precision: 0.9684 - recall: 0.9794
# Epoch 6: val_loss did not improve from 0.13264
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 26s 37ms/step - accuracy: 0.9734 - loss: 0.0733 - precision: 0.9684 - recall: 0.9794 - val_accuracy: 0.9603 - val_loss: 0.1479 - val_precision: 0.9460 - val_recall: 0.9755 - learning_rate: 1.0000e-04
# Epoch 7/100
# 687/689 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9744 - loss: 0.0713 - precision: 0.9668 - recall: 0.9830
# Epoch 7: val_loss did not improve from 0.13264
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 26s 36ms/step - accuracy: 0.9744 - loss: 0.0713 - precision: 0.9668 - recall: 0.9830 - val_accuracy: 0.9579 - val_loss: 0.1464 - val_precision: 0.9575 - val_recall: 0.9575 - learning_rate: 1.0000e-04
# Epoch 8/100
# 688/689 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9773 - loss: 0.0598 - precision: 0.9721 - recall: 0.9834
# Epoch 8: val_loss did not improve from 0.13264
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 26s 36ms/step - accuracy: 0.9773 - loss: 0.0598 - precision: 0.9721 - recall: 0.9834 - val_accuracy: 0.9626 - val_loss: 0.1423 - val_precision: 0.9504 - val_recall: 0.9755 - learning_rate: 5.0000e-05
# Epoch 9/100
# 688/689 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9796 - loss: 0.0540 - precision: 0.9751 - recall: 0.9846
# Epoch 9: val_loss did not improve from 0.13264
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 26s 36ms/step - accuracy: 0.9796 - loss: 0.0540 - precision: 0.9751 - recall: 0.9846 - val_accuracy: 0.9601 - val_loss: 0.1561 - val_precision: 0.9473 - val_recall: 0.9736 - learning_rate: 5.0000e-05
# Epoch 10/100
# 687/689 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9843 - loss: 0.0444 - precision: 0.9797 - recall: 0.9895
# Epoch 10: val_loss did not improve from 0.13264
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 26s 37ms/step - accuracy: 0.9843 - loss: 0.0444 - precision: 0.9797 - recall: 0.9895 - val_accuracy: 0.9585 - val_loss: 0.1513 - val_precision: 0.9481 - val_recall: 0.9693 - learning_rate: 5.0000e-05
# Epoch 11/100
# 688/689 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9831 - loss: 0.0475 - precision: 0.9793 - recall: 0.9875
# Epoch 11: val_loss did not improve from 0.13264
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 26s 37ms/step - accuracy: 0.9831 - loss: 0.0475 - precision: 0.9793 - recall: 0.9875 - val_accuracy: 0.9586 - val_loss: 0.1494 - val_precision: 0.9540 - val_recall: 0.9630 - learning_rate: 5.0000e-05
# Epoch 12/100
# 687/689 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9847 - loss: 0.0395 - precision: 0.9822 - recall: 0.9875
# Epoch 12: val_loss did not improve from 0.13264
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 26s 37ms/step - accuracy: 0.9847 - loss: 0.0395 - precision: 0.9822 - recall: 0.9875 - val_accuracy: 0.9599 - val_loss: 0.1609 - val_precision: 0.9486 - val_recall: 0.9718 - learning_rate: 5.0000e-05
# Epoch 13/100
# 687/689 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9871 - loss: 0.0378 - precision: 0.9841 - recall: 0.9904
# Epoch 13: val_loss did not improve from 0.13264
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 41s 37ms/step - accuracy: 0.9871 - loss: 0.0378 - precision: 0.9841 - recall: 0.9904 - val_accuracy: 0.9608 - val_loss: 0.1579 - val_precision: 0.9515 - val_recall: 0.9704 - learning_rate: 2.5000e-05
# Epoch 14/100
# 688/689 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9893 - loss: 0.0295 - precision: 0.9862 - recall: 0.9927
# Epoch 14: val_loss did not improve from 0.13264
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 26s 37ms/step - accuracy: 0.9893 - loss: 0.0295 - precision: 0.9862 - recall: 0.9927 - val_accuracy: 0.9604 - val_loss: 0.1640 - val_precision: 0.9467 - val_recall: 0.9751 - learning_rate: 2.5000e-05
# Epoch 15/100
# 687/689 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9890 - loss: 0.0296 - precision: 0.9866 - recall: 0.9918
# Epoch 15: val_loss did not improve from 0.13264
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 28s 39ms/step - accuracy: 0.9890 - loss: 0.0296 - precision: 0.9866 - recall: 0.9918 - val_accuracy: 0.9588 - val_loss: 0.1622 - val_precision: 0.9465 - val_recall: 0.9718 - learning_rate: 2.5000e-05
# Epoch 16/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9924 - loss: 0.0241 - precision: 0.9903 - recall: 0.9947
# Epoch 16: val_loss did not improve from 0.13264
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 26s 37ms/step - accuracy: 0.9924 - loss: 0.0241 - precision: 0.9903 - recall: 0.9947 - val_accuracy: 0.9610 - val_loss: 0.1687 - val_precision: 0.9493 - val_recall: 0.9733 - learning_rate: 2.5000e-05
# Epoch 17/100
# 688/689 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9923 - loss: 0.0222 - precision: 0.9896 - recall: 0.9952
# Epoch 17: val_loss did not improve from 0.13264
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.9923 - loss: 0.0222 - precision: 0.9896 - recall: 0.9952 - val_accuracy: 0.9601 - val_loss: 0.1724 - val_precision: 0.9486 - val_recall: 0.9722 - learning_rate: 2.5000e-05
# Epoch 18/100
# 688/689 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9928 - loss: 0.0205 - precision: 0.9918 - recall: 0.9938
# Epoch 18: val_loss did not improve from 0.13264
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 26s 37ms/step - accuracy: 0.9928 - loss: 0.0205 - precision: 0.9918 - recall: 0.9938 - val_accuracy: 0.9610 - val_loss: 0.1739 - val_precision: 0.9468 - val_recall: 0.9762 - learning_rate: 1.2500e-05
# Epoch 19/100
# 688/689 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9933 - loss: 0.0202 - precision: 0.9916 - recall: 0.9951
# Epoch 19: val_loss did not improve from 0.13264
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 43s 41ms/step - accuracy: 0.9933 - loss: 0.0202 - precision: 0.9916 - recall: 0.9951 - val_accuracy: 0.9612 - val_loss: 0.1752 - val_precision: 0.9484 - val_recall: 0.9747 - learning_rate: 1.2500e-05
# Epoch 20/100
# 687/689 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9950 - loss: 0.0189 - precision: 0.9936 - recall: 0.9964
# Epoch 20: val_loss did not improve from 0.13264
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 29s 41ms/step - accuracy: 0.9950 - loss: 0.0189 - precision: 0.9936 - recall: 0.9964 - val_accuracy: 0.9612 - val_loss: 0.1766 - val_precision: 0.9500 - val_recall: 0.9729 - learning_rate: 1.2500e-05
# Epoch 21/100
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9947 - loss: 0.0165 - precision: 0.9934 - recall: 0.9961
# Epoch 21: val_loss did not improve from 0.13264
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.9947 - loss: 0.0165 - precision: 0.9934 - recall: 0.9961 - val_accuracy: 0.9608 - val_loss: 0.1853 - val_precision: 0.9519 - val_recall: 0.9700 - learning_rate: 1.2500e-05
# Epoch 22/100
# 687/689 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9944 - loss: 0.0165 - precision: 0.9944 - recall: 0.9947
# Epoch 22: val_loss did not improve from 0.13264
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.9945 - loss: 0.0165 - precision: 0.9944 - recall: 0.9947 - val_accuracy: 0.9615 - val_loss: 0.1861 - val_precision: 0.9490 - val_recall: 0.9747 - learning_rate: 1.2500e-05
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 2.

# %%
import pandas as pd

def plot_history(history):
    hist_df = pd.DataFrame(history.history)

    plt.figure(figsize=(14,5))
    plt.subplot(1,2,1)
    plt.plot(hist_df["loss"], label="Training Loss")
    plt.plot(hist_df["val_loss"], label="Validation Loss")
    plt.legend()
    plt.title("Loss over Epochs")

    plt.subplot(1,2,2)
    plt.plot(hist_df["accuracy"], label="Training Accuracy")
    plt.plot(hist_df["val_accuracy"], label="Validation Accuracy")
    plt.legend()
    plt.title("Accuracy over Epochs")

    plt.show()

plot_history(history)
